# %%
import sys,os
sys.path.append('/home/marc/flow_ssl/')
import glob
import torch,dill
import torchvision.utils as vutils
import matplotlib.pyplot as plt
from flow_ssl.invertible import iConv2d,iSLReLU
from flow_ssl.invertible import SN
from flow_ssl.invertible import SqueezeLayer,padChannels,keepChannels,NNdownsample,iAvgPool2d
from flow_ssl.invertible import MeanOnlyBN, iBN
import numpy as np
import seaborn as sb
import torch.nn.functional as F
import pandas as pd
import timeit

# %%
bs = 32
c = 64
h = w = 8
Conv = iConv2d(c,c)

# %%
x = torch.randn(64,c,h,w)

# %%
y = Conv(x)

# %%
# %timeit Conv.logdet()

# %%
# %timeit Conv(x)

# %%
with torch.no_grad():
    # %timeit Conv.inverse(x)

# %%
bs = 32
c = 64
h = w = 8
Conv = iConv2d(c,c)
with torch.no_grad():
    for c in [16,32,64,128,256,512,1024]:
        print(f"Timings for c = {c}")
        Conv = iConv2d(c,c).cuda()
        x = torch.randn(bs,c,h,w).cuda()
#         print("conv")
#         %timeit Conv(x)
        y=Conv(x)
#         print("logdet")
#         %timeit ld = Conv.logdet()
        print("inverse")
        # %timeit x0 = Conv.inverse(y);torch.cuda.synchronize()
    
    c = 64
    Conv = iConv2d(c,c).cuda()
    for h in [4,8,16,32,64,128]:
        w=h
        print(f"Timings for h,w = {h}")
        x = torch.randn(bs,c,h,w).cuda();torch.cuda.synchronize()
#         print("conv")
#         %timeit Conv(x)
        y=Conv(x)
#         print("logdet")
#         %timeit ld = Conv.logdet()
        print("inverse")
        # %timeit x0 = Conv.inverse(y)
# Out:
# Timings for c = 16
# inverse
# 1.13 ms ± 95.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Timings for c = 32
# inverse
# 6.05 ms ± 650 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Timings for c = 64
# inverse
# 10.7 ms ± 375 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Timings for c = 128
# inverse
# 33.9 ms ± 1.48 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# Timings for c = 256
# inverse
# 125 ms ± 2.24 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# Timings for c = 512
# inverse
# 502 ms ± 927 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Timings for c = 1024
# inverse
# 2.62 s ± 26.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Timings for h,w = 4
# inverse
# 7.71 ms ± 470 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Timings for h,w = 8
# inverse
# 10.8 ms ± 455 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Timings for h,w = 16
# inverse
# 17.5 ms ± 282 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Timings for h,w = 32
# inverse
# 60 ms ± 28 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# Timings for h,w = 64
# inverse
# 264 ms ± 11 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Timings for h,w = 128
# inverse
# 1.09 s ± 13.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
channels = np.array([16,32,64,128,256,512,1024])
inverse_times_c = np.array([3440,9590,37700,133000,499000,2270000,11400000])
inverse_times_c_cuda = np.array([997,5780,10700,32800,126000,511000,2620000])
#inverse_sigmas_c = np.array([445,456,10200,5180])
logdet_times_c = np.array([397,397,1290,6340,23800,84900,390000])
#logdet_sigmas_c = np.array([.6,35,32,78])
conv_times_c = np.array([144,144,144,143,390,1270,4760])

height = np.array([4,8,16,32,64,128])
inverse_times_h = np.array([6750,32600,162000,727000,2930000,13500000])
inverse_times_h_cuda = np.array([7680,10700,17600,60800,258000,1100000])
#inverse_sigmas_h = np.array([78,2000,5000,16000,70000])
logdet_times_h = np.array([755,1300,3300,13400,54400,238000])
#logdet_sigmas_h = np.array([53,40,3,100,400])
conv_times_h = np.array([143,143,142,475,1670,6280])

# %%
df_channels = pd.DataFrame({'channels':channels,
                            'inverse_times':inverse_times_c,'inverse_sigmas':inverse_sigmas_c,
                            'logdet_times':logdet_times_c,'logdet_sigmas':logdet_sigmas_c,
                           'conv_times':conv_times_c})

# %%
df_channels.plot(x='channels',loglog=True)

# %%
import seaborn as sns
sns.set()
from matplotlib import rc

rc('text', usetex=True)
rc('text.latex', preamble=[r'\usepackage{sansmath}', r'\sansmath']) #r'\usepackage{DejaVuSans}'
rc('font',**{'family':'sans-serif','sans-serif':['DejaVu Sans']})
#plt.rcParams.update({'font.size': 50})
#rc('xtick.major', pad=12)
#rc('ytick.major', pad=12)
rc('grid', linewidth=1.3)
ms=20
lw=3
fs = 18
plt.plot(channels,1e-6*inverse_times_c,label=r"Conv$_W^{-1}(y)$",marker='.',ms=ms,lw=lw)
plt.plot(channels,1e-6*inverse_times_c_cuda,label=r"Conv$_W^{-1}(y)$ with $\phi$\&CUDA",marker='.',ms=ms,lw=lw)
plt.plot(channels,1e-6*logdet_times_c,label=r"$\log$ det ",marker='.',ms=ms,lw=lw)
plt.plot(channels,1e-6*conv_times_c,label=r"Conv$_W(x)$",marker='.',ms=ms,lw=lw)

plt.plot(channels,1e-6*channels**2,label=r"$O(d^2)$",ls='--',lw=lw)
#plt.plot(channels,6e-8*channels**3,label=r"$O(d^3)$",ls='--',lw=lw)
plt.xlabel("Channels d",fontsize=fs)
plt.ylabel(r"Time(s)",fontsize=fs)
plt.legend(fontsize=fs-2)
plt.yscale('log')
plt.xscale('log')
plt.xticks([16,64,256,1024], ["16", "64", "256", "1024"],fontsize=fs)
plt.yticks(fontsize=fs)

fig = plt.gcf()
fig.set_size_inches(5, 4)
plt.tight_layout()
fig.savefig('channels_runtime.pdf',bbox_layout="tight")

# %%
ms=20
lw=3
plt.plot(height,1e-6*inverse_times_h,label=r"Conv$_W^{-1}(y)$",marker='.',ms=ms,lw=lw)
plt.plot(height,1e-6*inverse_times_h_cuda,label=r"Conv$_W^{-1}(y)$ with $\phi$\&CUDA",marker='.',ms=ms,lw=lw)
plt.plot(height,1e-6*logdet_times_h,label=r"$\log$ det ",marker='.',ms=ms,lw=lw)
plt.plot(height,1e-6*conv_times_h,label=r"Conv$_W(x)$",marker='.',ms=ms,lw=lw)
#plt.plot(height,1e-4*height**2,label=r"$O(d^2)$",ls='--',lw=lw)
plt.plot(height,3e-5*np.log(height)*height**2,label=r"$O(m^2 \log(m))$",ls='--',lw=lw)
plt.xlabel(r"Input spatial size $m\times m$",fontsize=fs)
plt.ylabel(r"Time(s)",fontsize=fs)
plt.legend(fontsize=fs-2)
plt.yscale('log')
plt.xscale('log')
plt.xticks([4,16,64], [r"$4\times 4$",r"$16\times 16$",r"$64\times 64$"],fontsize=fs)
plt.yticks(fontsize=fs)
#plt.xlim([10,200])
fig = plt.gcf()
plt.tight_layout()
fig.set_size_inches(5, 4)
fig.savefig('hw_runtime.pdf',bbox_layout="tight")

# %%
for c in [16,32,64,128]:
    Conv = iConv2d(c,c)
    x = torch.randn(bs,c,h,w)
    # %timeit Conv(x)

# %%
print(timeit.timeit('[func(42) for func in (f,g,h)]', globals=globals()))
